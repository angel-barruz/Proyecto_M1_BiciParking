# %% [markdown]
# # Import DataBase

# %%
# Imports

import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd
import requests

# %%
connection_string = 'mysql://ironhack_user:%Vq=c>G5@173.201.189.217/BiciMAD'
engine = create_engine(connection_string)

# %%
inspector = inspect(engine)
inspector.get_table_names()
#type(inspector)
# Out:
# ['bicimad_stations', 'bicipark_stations']

# %%
query = '''
SELECT *
FROM bicimad_stations
'''
df_1 = pd.read_sql_query(query, engine)
df_1
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
# Separación de Latitud y Longitud
df_1[['Latitud','Longitud']]=df_1['geometry.coordinates'].str.split(',',expand=True)
df_1.head (15)
# Out:
#     id                         name  light number  \
# 0    1        1a - Puerta del Sol A      3     1a
# 1    2        1b - Puerta del Sol B      3     1b
# 2    3              2 - Miguel Moya      3      2
# 3    4       3 - Plaza Conde Suchil      2      3
# 4    5                 4 - Malasaña      1      4
# 5    6               5 - Fuencarral      1      5
# 6    7      6 - Colegio Arquitectos      3      6
# 7    8                7 - Hortaleza      3      7
# 8    9          8 - Alonso Martínez      1      8
# 9   10      9 - Plaza de San Miguel      2      9
# 10  11  10 - Marqués de la Ensenada      2     10
# 11  12              11 - San Andrés      1     11
# 12  13        12 - San Hermenegildo      1     12
# 13  14             13 - Conde Duque      1     13
# 14  15       14 - Ventura Rodríguez      3     14
#
#                                      address  activate  no_available  \
# 0                        Puerta del Sol nº 1         1             1
# ...

# %%
# Limpieza de datos "[]"
df_1 ['Latitud'] = df_1['Latitud'].str.replace("[","")
df_1 ['Longitud'] = df_1['Longitud'].str.replace("]","")
df_1.head(5)
# Out:
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12648\2409625264.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_1 ['Latitud'] = df_1['Latitud'].str.replace("[","")
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12648\2409625264.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_1 ['Longitud'] = df_1['Longitud'].str.replace("]","")
#    id                    name  light number  \
# 0   1   1a - Puerta del Sol A      3     1a
# 1   2   1b - Puerta del Sol B      3     1b
# 2   3         2 - Miguel Moya      3      2
# 3   4  3 - Plaza Conde Suchil      2      3
# 4   5            4 - Malasaña      1      4
#
# ...

# %%
print(type(df_1['Latitud']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Convertir string a float
df_1['Latitud'] = df_1['Latitud'].astype(float)
df_1['Longitud'] = df_1['Longitud'].astype(float)
df_1
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...
